# %%
import pandas as pd

# %%
# Data Loading

data = pd.read_csv("C:/Users/Admin/Downloads/datasets/Combined_dataset.csv")
df = pd.DataFrame(data)
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
# Data Exploration

df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
# Data Cleaning

df.isnull()
# Out:
#      product_id  title  product_description  rating  ratings_count  \
# 0         False  False                False   False          False
# 1         False  False                False   False          False
# 2         False  False                False   False          False
# 3         False  False                False   False          False
# 4         False  False                False   False          False
# ..          ...    ...                  ...     ...            ...
# 995       False  False                False   False          False
# 996       False  False                False   False          False
# 997       False  False                False   False          False
# 998       False  False                False   False          False
# 999       False  False                False   False          False
#
#      initial_price  discount  final_price  currency  images  ...  \
# 0            False     False        False     False   False  ...
# ...

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df1 = df.fillna(0)
df1
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df1["seller_name"] = df1["seller_name"].fillna("HellOName")
df1
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df1.dropna()
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.dropna()
# Out:
#      product_id            title  \
# 418    18689340   Flying Machine
# 752    18241626         Roadster
# 753    18241400         Roadster
# 754    18241644         Roadster
# 755    18240570    all about you
# 756    18240582    all about you
# 757    18337610         Roadster
# 760    18241294         Roadster
# 762    18241298         Roadster
# 904    18937522  her by invictus
#
#                                    product_description  rating  ratings_count  \
# 418  Women Black Wide Leg High-Rise Light Fade Crop...     4.3             36
# 752  The  Lifestyle Co. Women Maroon & Black Ribbed...     4.5             25
# 753     Women Black & White Geometric Pullover Sweater     3.8             57
# 754     The  Lifestyle Co. Women Pink Acrylic Pullover     4.3             55
# 755             Women Navy Blue & Red Checked Pullover     4.3             53
# 756                   Women Maroon Cable Knit Pullover     4.4             39
# ...

# %%
df1[df1["title"] == "Roadster"]
# Out:
#      product_id     title                                product_description  \
# 359    14991614  Roadster        Men Green Brand Logo Detail Tailored Jacket
# 394    18094702  Roadster  The  Lifestyle Co Men Blue Slim Fit Mid-Rise S...
# 431    15049188  Roadster  Pink & Black Geometric Printed Basic Smocked D...
# 564    17377642  Roadster  The  Lifestyle Co Men Navy Blue Checked Pure C...
# 593    17289046  Roadster  The  Lifestyle Co. Women Pure Cotton Puff Slee...
# 609    17289100  Roadster  The  Life Co. Spread Collar Pure Cotton Casual...
# 633    13470886  Roadster  The  Lifestyle Co Greenturn Women Teal Blue So...
# 634    13722850  Roadster  X Discovery Adventures Women Olive Green Opaqu...
# 730    18430170  Roadster  The  Lifestyle Co. Women Geometric Self Design...
# 741    11990920  Roadster  Women Pink Self Design Turtle Neck Pullover Sw...
# 746    11990978  Roadster  Women Red & Grey Melange Abstract Self Design ...
# ...

# %%
df1[df1["rating"] > 4.4]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# 7      18602872            My Room
# 8      18602850            My Room
# ..          ...                ...
# 985    17981742               MVMT
# 986    17697474              Timex
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# 7    Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# 8    Ethnic Print 144 TC Super King Bedsheet with 2...     4.5             22
# ...

# %%
df1[(df1["rating"] > 4.5) & (df1["ratings_count"] > 100)]
# Out:
#      product_id       title  \
# 42     16696094  Van Heusen
# 422    21184968    HERE&NOW
# 649    18903374       Levis
#
#                                    product_description  rating  ratings_count  \
# 42   Men Swift Dry High Stretch Mesh AIR Series Act...     4.6            192
# 422          Women Flared Heavy Fade Stretchable Jeans     4.6            111
# 649                Women Blue Pure Cotton Casual Shirt     4.6            168
#
#      initial_price  discount  final_price currency  \
# 42             649       0.0    "₹649.00"      INR
# 422           2399      68.0    "₹767.00"      INR
# 649           2599      45.0  "₹2,079.00"      INR
#
#                                                 images  ...  \
# 42   http://assets.myntassets.com/assets/images/166...  ...
# 422  http://assets.myntassets.com/assets/images/211...  ...
# 649  http://assets.myntassets.com/assets/images/189...  ...
#
#                                        amount_of_stars  \
# ...

# %%
df1["final_price"].head(10)
# Out:
# 0    "₹3,995.00"
# 1    "₹2,899.00"
# 2    "₹2,999.00"
# 3    "₹1,675.00"
# 4    "₹2,899.00"
# 5    "₹1,399.00"
# 6    "₹1,399.00"
# 7    "₹2,999.00"
# 8    "₹2,999.00"
# 9    "₹2,199.00"
# Name: final_price, dtype: object

# %%
df1[["initial_price","final_price"]].dtypes
# Out:
# initial_price     int64
# final_price      object
# dtype: object

# %%
df1["final_price"] = (
    df["final_price"]
    .astype(str)
    .str.replace("₹", "", regex=False)
    .str.replace(",", "", regex=False)
)

df["final_price"] = pd.to_numeric(df["final_price"], errors="coerce")

# %%
# df1[["initial_price","final_price"]].dtypes
df1["final_price"].dtype
# Out:
# dtype('O')

# %%
df1[["title","initial_price","rating"]]
# Out:
#               title  initial_price  rating
# 0       Lino Perros           3995     3.8
# 1    Tommy Hilfiger           2899     4.5
# 2             Lavie           2999     4.4
# 3            F Gear           1675     4.4
# 4         MYTRIDENT           2899     4.7
# ..              ...            ...     ...
# 995           KREDO          11890     3.5
# 996           GUESS           8900     5.0
# 997        GIORDANO           7950     2.8
# 998        Fastrack           3295     4.3
# 999         BOLDFIT            699     3.8
#
# [1000 rows x 3 columns]

# %%
df1
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df1[df1["title"] == "Lavie"][["rating","ratings_count"]]
# Out:
#      rating  ratings_count
# 2       4.4            226
# 980     4.4             21

# %%
df1[df1["title"] == "Lavie"]
# Out:
#      product_id  title                                product_description  \
# 2      17633752  Lavie                     Aries Women Pink Mini Backpack
# 980    18864968  Lavie  Glossy Sacy Women Pink Animal Textured Zip Aro...
#
#      rating  ratings_count  initial_price  discount final_price currency  \
# 2       4.4            226           2999      65.0   "2999.00"      INR
# 980     4.4             21           1999      65.0   "1999.00"      INR
#
#                                                 images  ...  \
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 980  http://assets.myntassets.com/assets/images/188...  ...
#
#                                        amount_of_stars what_customers_said  \
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                   0
# 980  {"1_star":0,"2_stars":0,"3_stars":3,"4_stars":...                   0
#
#     seller_name           sizes  \
# 2             0  [{"size":"S"}]
# 980           0  [{"size":"L"}]
#
# ...

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.drop_duplicates()   
# this removes duplicates from the dataset but here we dont have any duplicate value in dataset..

# %%
# df.drop_duplicates(subset=["title"])
# Remove Duplicates Based on Specific Columns

# %%
# df1["price_difference"]

# %%
df1["final_price"] = (
    df1["final_price"]
    .astype(str)
    .str.replace(r"[^0-9.]", "", regex=True)
)

df1["final_price"] = pd.to_numeric(df1["final_price"])

# %%
df1["final_price"].dtype
# Out:
# dtype('float64')

# %%
df1["final_price"]
# Out:
# 0       3995.0
# 1       2899.0
# 2       2999.0
# 3       1675.0
# 4       2899.0
#         ...
# 995    11890.0
# 996     8900.0
# 997     7950.0
# 998     2636.0
# 999      699.0
# Name: final_price, Length: 1000, dtype: float64

# %%
# Feature Engineering

df1["price_difference"] = df1["initial_price"] - df1["final_price"]

# %%
df1[["initial_price","final_price","price_difference"]]
# Out:
#      initial_price  final_price  price_difference
# 0             3995       3995.0               0.0
# 1             2899       2899.0               0.0
# 2             2999       2999.0               0.0
# 3             1675       1675.0               0.0
# 4             2899       2899.0               0.0
# ..             ...          ...               ...
# 995          11890      11890.0               0.0
# 996           8900       8900.0               0.0
# 997           7950       7950.0               0.0
# 998           3295       2636.0             659.0
# 999            699        699.0               0.0
#
# [1000 rows x 3 columns]

# %%
df1["popularity_score"] = df1["rating"] * df1["ratings_count"]

# %%
df1[["rating","ratings_count","popularity_score"]]
# Out:
#      rating  ratings_count  popularity_score
# 0       3.8             15              57.0
# 1       4.5             67             301.5
# 2       4.4            226             994.4
# 3       4.4           1052            4628.8
# 4       4.7             12              56.4
# ..      ...            ...               ...
# 995     3.5             11              38.5
# 996     5.0             22             110.0
# 997     2.8              5              14.0
# 998     4.3             17              73.1
# 999     3.8            161             611.8
#
# [1000 rows x 3 columns]

# %%
df1["main_category"] = df1["category"].str.split("|").str[0]

# %%
df1["category"].head()
# Out:
# 0    backpacks
# 1    backpacks
# 2    backpacks
# 3    backpacks
# 4    bath-robe
# Name: category, dtype: object

# %%
df1[["initial_price","final_price","price_difference",
    "rating","ratings_count","popularity_score"]].head()
# Out:
#    initial_price  final_price  price_difference  rating  ratings_count  \
# 0           3995       3995.0               0.0     3.8             15
# 1           2899       2899.0               0.0     4.5             67
# 2           2999       2999.0               0.0     4.4            226
# 3           1675       1675.0               0.0     4.4           1052
# 4           2899       2899.0               0.0     4.7             12
#
#    popularity_score
# 0              57.0
# 1             301.5
# 2             994.4
# 3            4628.8
# 4              56.4

# %%
df1["rating"].describe()
# Out:
# count    1000.0000
# mean        3.6215
# std         1.3744
# min         0.0000
# 25%         3.7000
# 50%         4.1000
# 75%         4.3000
# max         5.0000
# Name: rating, dtype: float64

# %%
# Analysis

df1["category"].value_counts()
# Out:
# category
# tops                  122
# dresses               100
# shirts                 97
# jeans                  57
# sports-shoes           51
#                      ...
# lounge-pants            1
# lounge-shorts           1
# mangalsutra             1
# mobile-accessories      1
# yoga-mats               1
# Name: count, Length: 97, dtype: int64

# %%
df1["category"].value_counts().head(10)
# Out:
# category
# tops            122
# dresses         100
# shirts           97
# jeans            57
# sports-shoes     51
# tshirts          39
# earrings         34
# sweaters         34
# jackets          29
# casual-shoes     23
# Name: count, dtype: int64

# %%
df1[["rating","final_price"]].corr(numeric_only=True)
# Out:
#                rating  final_price
# rating       1.000000     0.084587
# final_price  0.084587     1.000000

# %%
df1[df1["rating"] > 4.5][["title","rating","final_price"]]
# Out:
#               title  rating  final_price
# 4         MYTRIDENT     4.7       2899.0
# 7           My Room     4.7       2999.0
# 22       London Rag     5.0       3839.0
# 32            VStar     4.6        345.0
# 38        KARATCART     4.6        815.0
# ..              ...     ...          ...
# 963         BULLMER     4.8        799.0
# 968  Mad Over Print     4.8        671.0
# 986           Timex     4.9       1596.0
# 992           CASIO     4.6       3235.0
# 996           GUESS     5.0       8900.0
#
# [104 rows x 3 columns]

# %%
df1[["rating","ratings_count"]].corr(numeric_only=True)
# Out:
#                  rating  ratings_count
# rating         1.000000       0.125795
# ratings_count  0.125795       1.000000

# %%
df1.groupby("category")["rating"].mean().sort_values(ascending=False)
# Out:
# category
# cutlery                   5.00
# shaving-essentials        4.90
# face-wash-and-cleanser    4.80
# bath-robe                 4.70
# chair-cover               4.70
#                           ...
# sherwani                  1.62
# runners                   1.50
# showpieces                0.00
# mobile-accessories        0.00
# candle-holders            0.00
# Name: rating, Length: 97, dtype: float64

# %%
df1.groupby("category")["final_price"].mean().sort_values(ascending=False)
# Out:
# category
# trolley-bag            17995.000000
# headphones              5832.333333
# sherwani                5764.600000
# watches                 5392.800000
# sports-shoes            4228.470588
#                            ...
# camisoles                247.500000
# outdoor-masks            224.000000
# belts                    223.000000
# hair-cream-and-mask      219.000000
# hair-masks               219.000000
# Name: final_price, Length: 97, dtype: float64

# %%
df1.groupby("category")["product_id"].count().sort_values(ascending=False)
# Out:
# category
# tops                  122
# dresses               100
# shirts                 97
# jeans                  57
# sports-shoes           51
#                      ...
# lounge-pants            1
# lounge-shorts           1
# mangalsutra             1
# mobile-accessories      1
# yoga-mats               1
# Name: product_id, Length: 97, dtype: int64

# %%
# Visualization

import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.hist(df["rating"], bins=10)
plt.title("Distribution of Product Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
top_categories = df["category"].value_counts().head(10)

plt.figure(figsize=(10,5))
top_categories.plot(kind="bar")
plt.title("Top 10 Product Categories")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df["final_price"].dropna())
plt.title("Boxplot of Final Price")
plt.ylabel("Price")
plt.show()

# %%
df1[["price_difference","popularity_score","main_category"]].head()
# Out:
#    price_difference  popularity_score main_category
# 0               0.0              57.0     backpacks
# 1               0.0             301.5     backpacks
# 2               0.0             994.4     backpacks
# 3               0.0            4628.8     backpacks
# 4               0.0              56.4     bath-robe

# %%
# # insights..

# Key Findings
# The dataset contains products from multiple categories, with some categories having significantly more products than others,
# indicating an uneven product distribution.

# Most products have ratings above average, suggesting generally positive customer feedback across the platform.

# Products with a higher number of ratings tend to have better popularity scores, 
# indicating that customer engagement strongly influences product visibility and trust.

# The newly created price_difference feature shows that several products are offered at substantial discounts,
# which may influence customer purchasing decisions.

# Category-level analysis revealed that certain categories consistently achieve higher ratings and popularity scores compared to others.

# Highly rated and popular products should be highlighted in recommendations, advertisements, 
# and promotional campaigns to increase sales and customer satisfaction.

# Categories with strong performance can be prioritized for inventory expansion and targeted marketing strategies.

# Products with low ratings should be reviewed for quality issues, pricing concerns, or customer service improvements.

# Significant discounts appear to attract customer attention and may contribute to increased engagement; therefore, 
# discount strategies can be used to boost sales.

# The popularity_score metric can help identify trending products and support data-driven business decisions related to product placement and promotions.

# The dataset was successfully cleaned, transformed, and analyzed using Pandas. Missing values were handled, 
# duplicates were checked, new features were engineered, and meaningful insights were extracted through exploratory data analysis and visualization. 
# The results provide valuable information for understanding product performance, customer engagement, 
# and category-level trends.

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Admin

# %%
df1
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df1.to_csv("Final_Combined.csv")

# %%
df1[(df1["discount"] > 0) & (df1["initial_price"] == df1["final_price"])].shape
# Out:
# (252, 27)

# %%
df1["calculated_final_price"] = (
    df1["initial_price"] * (100 - df1["discount"]) / 100
).round(0)

# %%
df1["calculated_final_price"]
# Out:
# 0      1678.0
# 1      1884.0
# 2      1050.0
# 3       804.0
# 4      2406.0
#         ...
# 995    5945.0
# 996    4895.0
# 997    3975.0
# 998    2636.0
# 999     482.0
# Name: calculated_final_price, Length: 1000, dtype: float64

# %%
df1[["initial_price","discount","final_price","calculated_final_price"]].head(20)
# Out:
#     initial_price  discount  final_price  calculated_final_price
# 0            3995      58.0       3995.0                  1678.0
# 1            2899      35.0       2899.0                  1884.0
# 2            2999      65.0       2999.0                  1050.0
# 3            1675      52.0       1675.0                   804.0
# 4            2899      17.0       2899.0                  2406.0
# 5            1399       0.0       1399.0                  1399.0
# 6            1399      65.0       1399.0                   490.0
# 7            2999      54.0       2999.0                  1380.0
# 8            2999      54.0       2999.0                  1380.0
# 9            2199      53.0       2199.0                  1034.0
# 10           2199      46.0       2199.0                  1187.0
# 11           3329      74.0        865.0                   866.0
# 12           1499      73.0        404.0                   405.0
# ...

# %%
df1.to_csv("Final_File.csv",index=False)
